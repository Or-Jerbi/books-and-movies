# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib as mpl
import matplotlib.pyplot as plt      
import math
import seaborn as sns
from collections import Counter
from sklearn.decomposition import PCA
# %matplotlib inline

# %%
df=pd.read_csv('Data set after cleaning.csv')
df['Rating count']=df['Rating count'].astype(float)
df['Num of awards']=df['Num of awards'].astype(float)
df['Edition language']=df['Edition language'].astype(float)
df['Reading age']=df['Reading age'].astype(float)
df
# Out:
#       Title  Name of author  Publisher  Genre  Rating  Rating count  \
# 0         0             939         29     58    3.59         112.0
# 1         1            1318        296      3    4.32        8047.0
# 2         2             907        344     76    3.63       83871.0
# 3         3             222        672     25    3.43       89907.0
# 4         4             111        635     58    4.15      283010.0
# ...     ...             ...        ...    ...     ...           ...
# 2077   2058            1011        456     25    3.71        4729.0
# 2078   2059            1356        528     19    3.97          29.0
# 2079   2060             995        296     19    4.41         142.0
# 2080   2061             293        257     52    3.99       13779.0
# 2081   2062              18         62     25    3.69       19360.0
#
#       Review count  Book cover  Release date  Num of pages  Edition language  \
# ...

# %%
sr = df['There is a movie'].value_counts()[:2]
sr.plot(kind='pie',labels=['Yes','No'],autopct='%1.1f%%')
plt.title('Books made into movies')
# Out:
# Text(0.5, 1.0, 'Books made into movies')

# %%
plt.scatter(df['Num of awards'], df['Review count'])
plt.xlabel('Num of awards')
plt.ylabel('Review count')
plt.show()
df['Num of awards'].corr(df['Review count'])
# Out:
# 0.4174365254203101

# %%
df['Release date'].hist(bins=10, grid = False, rwidth=0.9, color ='blue')
plt.xlabel('Release date')
plt.ylabel('Amount')
plt.title('Year')
plt.show()
df['There is a movie'].corr(df['Release date'])
# Out:
# -0.47189569943471366

# %%
from mpl_toolkits.mplot3d import Axes3D
ax=plt.axes(projection='3d')
x = df['Rating count']
y= df['Review count']
z=df['Rating']

plt.xlabel('Rating count')
plt.ylabel('Review count')
ax.scatter3D(x,y,z, c=z, depthshade=False)

# %%
ct = pd.crosstab(df['Reading age'] , df['There is a movie'], normalize ='index')
ct.plot.bar(stacked=True)
plt.show()
